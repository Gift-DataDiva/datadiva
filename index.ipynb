# %%
import pandas as pd

# %%
df=pd.read_csv(r"food industry dataset 1.csv")

# %%
df
# Out:
#        Order_ID Customer_ID Restaurant Menu_Item  Order_Date Delivery_Date  \
# 0     ORD000001    CUST4876   Outlet_D       NaN    7/3/2023      7/3/2023
# 1     ORD000002    CUST2603   Outlet_B     Pizza   2/22/2023     2/22/2023
# 2     ORD000003    CUST4424   Outlet_B     Sushi    5/9/2023     5/10/2023
# 3     ORD000004    CUST1110   Outlet_C     Sushi  12/17/2023    12/19/2023
# 4     ORD000005    CUST5454   Outlet_C     Sushi    9/2/2023      9/4/2023
# ...         ...         ...        ...       ...         ...           ...
# 9995  ORD009996    CUST1954   Outlet_B    Burger   6/21/2023     6/22/2023
# 9996  ORD009997    CUST5428   Outlet_C     Pasta   8/28/2023     8/30/2023
# 9997  ORD009998    CUST8672   Outlet_C     Salad  11/15/2023    11/17/2023
# 9998  ORD009999    CUST3187   Outlet_D      Wrap   1/18/2023     1/20/2023
# 9999  ORD010000    CUST4321   Outlet_B     Pizza    8/2/2023      8/3/2023
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order_ID           10000 non-null  object
#  1   Customer_ID        10000 non-null  object
#  2   Restaurant         10000 non-null  object
#  3   Menu_Item          9800 non-null   object
#  4   Order_Date         10000 non-null  object
#  5   Delivery_Date      9900 non-null   object
#  6   Quantity           10000 non-null  int64
#  7   Unit_Price         9866 non-null   float64
#  8   Total_Cost         10000 non-null  float64
#  9   Supplier           10000 non-null  object
#  10  Inventory_Stock    10000 non-null  int64
#  11  Expiry_Date        10000 non-null  object
#  12  Inspection_Status  6038 non-null   object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 1015.8+ KB

# %%
df["Menu_Item"]=df["Menu_Item"].fillna("pizza")

# %%
df
# Out:
#        Order_ID Customer_ID Restaurant Menu_Item  Order_Date Delivery_Date  \
# 0     ORD000001    CUST4876   Outlet_D     pizza    7/3/2023      7/3/2023
# 1     ORD000002    CUST2603   Outlet_B     Pizza   2/22/2023     2/22/2023
# 2     ORD000003    CUST4424   Outlet_B     Sushi    5/9/2023     5/10/2023
# 3     ORD000004    CUST1110   Outlet_C     Sushi  12/17/2023    12/19/2023
# 4     ORD000005    CUST5454   Outlet_C     Sushi    9/2/2023      9/4/2023
# ...         ...         ...        ...       ...         ...           ...
# 9995  ORD009996    CUST1954   Outlet_B    Burger   6/21/2023     6/22/2023
# 9996  ORD009997    CUST5428   Outlet_C     Pasta   8/28/2023     8/30/2023
# 9997  ORD009998    CUST8672   Outlet_C     Salad  11/15/2023    11/17/2023
# 9998  ORD009999    CUST3187   Outlet_D      Wrap   1/18/2023     1/20/2023
# 9999  ORD010000    CUST4321   Outlet_B     Pizza    8/2/2023      8/3/2023
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order_ID           10000 non-null  object
#  1   Customer_ID        10000 non-null  object
#  2   Restaurant         10000 non-null  object
#  3   Menu_Item          10000 non-null  object
#  4   Order_Date         10000 non-null  object
#  5   Delivery_Date      9900 non-null   object
#  6   Quantity           10000 non-null  int64
#  7   Unit_Price         9866 non-null   float64
#  8   Total_Cost         10000 non-null  float64
#  9   Supplier           10000 non-null  object
#  10  Inventory_Stock    10000 non-null  int64
#  11  Expiry_Date        10000 non-null  object
#  12  Inspection_Status  6038 non-null   object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 1015.8+ KB

# %%
df["Delivery_Date"]=df["Delivery_Date"].fillna("2/22/2023")

# %%
df
# Out:
#        Order_ID Customer_ID Restaurant Menu_Item  Order_Date Delivery_Date  \
# 0     ORD000001    CUST4876   Outlet_D     pizza    7/3/2023      7/3/2023
# 1     ORD000002    CUST2603   Outlet_B     Pizza   2/22/2023     2/22/2023
# 2     ORD000003    CUST4424   Outlet_B     Sushi    5/9/2023     5/10/2023
# 3     ORD000004    CUST1110   Outlet_C     Sushi  12/17/2023    12/19/2023
# 4     ORD000005    CUST5454   Outlet_C     Sushi    9/2/2023      9/4/2023
# ...         ...         ...        ...       ...         ...           ...
# 9995  ORD009996    CUST1954   Outlet_B    Burger   6/21/2023     6/22/2023
# 9996  ORD009997    CUST5428   Outlet_C     Pasta   8/28/2023     8/30/2023
# 9997  ORD009998    CUST8672   Outlet_C     Salad  11/15/2023    11/17/2023
# 9998  ORD009999    CUST3187   Outlet_D      Wrap   1/18/2023     1/20/2023
# 9999  ORD010000    CUST4321   Outlet_B     Pizza    8/2/2023      8/3/2023
#
# ...

# %%
df["Unit_Price"]=df["Unit_Price"].fillna("11.4")

# %%
df
# Out:
#        Order_ID Customer_ID Restaurant Menu_Item  Order_Date Delivery_Date  \
# 0     ORD000001    CUST4876   Outlet_D     pizza    7/3/2023      7/3/2023
# 1     ORD000002    CUST2603   Outlet_B     Pizza   2/22/2023     2/22/2023
# 2     ORD000003    CUST4424   Outlet_B     Sushi    5/9/2023     5/10/2023
# 3     ORD000004    CUST1110   Outlet_C     Sushi  12/17/2023    12/19/2023
# 4     ORD000005    CUST5454   Outlet_C     Sushi    9/2/2023      9/4/2023
# ...         ...         ...        ...       ...         ...           ...
# 9995  ORD009996    CUST1954   Outlet_B    Burger   6/21/2023     6/22/2023
# 9996  ORD009997    CUST5428   Outlet_C     Pasta   8/28/2023     8/30/2023
# 9997  ORD009998    CUST8672   Outlet_C     Salad  11/15/2023    11/17/2023
# 9998  ORD009999    CUST3187   Outlet_D      Wrap   1/18/2023     1/20/2023
# 9999  ORD010000    CUST4321   Outlet_B     Pizza    8/2/2023      8/3/2023
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order_ID           10000 non-null  object
#  1   Customer_ID        10000 non-null  object
#  2   Restaurant         10000 non-null  object
#  3   Menu_Item          10000 non-null  object
#  4   Order_Date         10000 non-null  object
#  5   Delivery_Date      10000 non-null  object
#  6   Quantity           10000 non-null  int64
#  7   Unit_Price         10000 non-null  object
#  8   Total_Cost         10000 non-null  float64
#  9   Supplier           10000 non-null  object
#  10  Inventory_Stock    10000 non-null  int64
#  11  Expiry_Date        10000 non-null  object
#  12  Inspection_Status  6038 non-null   object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 1015.8+ KB

# %%
df["Inspection_Status"]=df["Inspection_Status"].fillna("Pending")

# %%
df
# Out:
#        Order_ID Customer_ID Restaurant Menu_Item  Order_Date Delivery_Date  \
# 0     ORD000001    CUST4876   Outlet_D     pizza    7/3/2023      7/3/2023
# 1     ORD000002    CUST2603   Outlet_B     Pizza   2/22/2023     2/22/2023
# 2     ORD000003    CUST4424   Outlet_B     Sushi    5/9/2023     5/10/2023
# 3     ORD000004    CUST1110   Outlet_C     Sushi  12/17/2023    12/19/2023
# 4     ORD000005    CUST5454   Outlet_C     Sushi    9/2/2023      9/4/2023
# ...         ...         ...        ...       ...         ...           ...
# 9995  ORD009996    CUST1954   Outlet_B    Burger   6/21/2023     6/22/2023
# 9996  ORD009997    CUST5428   Outlet_C     Pasta   8/28/2023     8/30/2023
# 9997  ORD009998    CUST8672   Outlet_C     Salad  11/15/2023    11/17/2023
# 9998  ORD009999    CUST3187   Outlet_D      Wrap   1/18/2023     1/20/2023
# 9999  ORD010000    CUST4321   Outlet_B     Pizza    8/2/2023      8/3/2023
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order_ID           10000 non-null  object
#  1   Customer_ID        10000 non-null  object
#  2   Restaurant         10000 non-null  object
#  3   Menu_Item          10000 non-null  object
#  4   Order_Date         10000 non-null  object
#  5   Delivery_Date      10000 non-null  object
#  6   Quantity           10000 non-null  int64
#  7   Unit_Price         10000 non-null  object
#  8   Total_Cost         10000 non-null  float64
#  9   Supplier           10000 non-null  object
#  10  Inventory_Stock    10000 non-null  int64
#  11  Expiry_Date        10000 non-null  object
#  12  Inspection_Status  10000 non-null  object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 1015.8+ KB

# %%
import matplotlib.pyplot as plt

# %%
val =df["Total_Cost"].max()/6

# %%
bins=[0,val,val*2,val*3,val*4,val*5,val*6]
labels=["<100k","100-500k","500-1m","1m-5m","5m-10m","10m"]

# %%
val*4
# Out:
# 133.06666666666666

# %%
df["cost_bucket"]=pd.cut(df["Total_Cost"],bins=bins, labels=labels, include_lowest=True)

# %%
df
# Out:
#        Order_ID Customer_ID Restaurant Menu_Item  Order_Date Delivery_Date  \
# 0     ORD000001    CUST4876   Outlet_D     pizza    7/3/2023      7/3/2023
# 1     ORD000002    CUST2603   Outlet_B     Pizza   2/22/2023     2/22/2023
# 2     ORD000003    CUST4424   Outlet_B     Sushi    5/9/2023     5/10/2023
# 3     ORD000004    CUST1110   Outlet_C     Sushi  12/17/2023    12/19/2023
# 4     ORD000005    CUST5454   Outlet_C     Sushi    9/2/2023      9/4/2023
# ...         ...         ...        ...       ...         ...           ...
# 9995  ORD009996    CUST1954   Outlet_B    Burger   6/21/2023     6/22/2023
# 9996  ORD009997    CUST5428   Outlet_C     Pasta   8/28/2023     8/30/2023
# 9997  ORD009998    CUST8672   Outlet_C     Salad  11/15/2023    11/17/2023
# 9998  ORD009999    CUST3187   Outlet_D      Wrap   1/18/2023     1/20/2023
# 9999  ORD010000    CUST4321   Outlet_B     Pizza    8/2/2023      8/3/2023
#
# ...

# %%
Total_Cost_sum = df.groupby("cost_bucket", observed=True)["Total_Cost"].sum()

# %%
Total_Cost_sum
# Out:
# cost_bucket
# <100k        63112.88
# 100-500k    132762.26
# 500-1m      146448.45
# 1m-5m       121765.60
# 5m-10m       98091.92
# 10m          54421.29
# Name: Total_Cost, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.bar(Total_Cost_sum.index.astype(str), Total_Cost_sum.values,color="skyblue")
plt.title("Total Total Cost by cost Bucket")
plt.xlabel("Cost Bucket")
plt.ylabel("Total Total Cost")
plt.xticks(rotation=45)
plt.grid(True, axis="y")
plt.tight_layout()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order_ID           10000 non-null  object
#  1   Customer_ID        10000 non-null  object
#  2   Restaurant         10000 non-null  object
#  3   Menu_Item          10000 non-null  object
#  4   Order_Date         10000 non-null  object
#  5   Delivery_Date      10000 non-null  object
#  6   Quantity           10000 non-null  int64
#  7   Unit_Price         10000 non-null  object
#  8   Total_Cost         10000 non-null  float64
#  9   Supplier           10000 non-null  object
#  10  Inventory_Stock    10000 non-null  int64
#  11  Expiry_Date        10000 non-null  object
#  12  Inspection_Status  10000 non-null  object
#  13  cost_bucket        10000 non-null  category
# dtypes: category(1), float64(1), int64(2), object(10)
# memory usage: 1.0+ MB

# %%
val =df["Unit_Price"].astype(float).max()/8

# %%
val
# Out:
# 2.5

# %%
df["Unit_Price"] = df["Unit_Price"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order_ID           10000 non-null  object
#  1   Customer_ID        10000 non-null  object
#  2   Restaurant         10000 non-null  object
#  3   Menu_Item          10000 non-null  object
#  4   Order_Date         10000 non-null  object
#  5   Delivery_Date      10000 non-null  object
#  6   Quantity           10000 non-null  int64
#  7   Unit_Price         10000 non-null  float64
#  8   Total_Cost         10000 non-null  float64
#  9   Supplier           10000 non-null  object
#  10  Inventory_Stock    10000 non-null  int64
#  11  Expiry_Date        10000 non-null  object
#  12  Inspection_Status  10000 non-null  object
#  13  cost_bucket        10000 non-null  category
#  14  cost_name          10000 non-null  category
# ...

# %%
bins=[0,val,val*2,val*3,val*4,val*5,val*6,val*7,val*8]
labels=["<10k","10-50k","50-100k","100-500k","500k-1m","1-5m","5-10m","50m"]

# %%
df["cost_name"]=pd.cut(df["Unit_Price"],bins=bins, labels=labels, include_lowest=True)

# %%
df
# Out:
#        Order_ID Customer_ID Restaurant Menu_Item  Order_Date Delivery_Date  \
# 0     ORD000001    CUST4876   Outlet_D     pizza    7/3/2023      7/3/2023
# 1     ORD000002    CUST2603   Outlet_B     Pizza   2/22/2023     2/22/2023
# 2     ORD000003    CUST4424   Outlet_B     Sushi    5/9/2023     5/10/2023
# 3     ORD000004    CUST1110   Outlet_C     Sushi  12/17/2023    12/19/2023
# 4     ORD000005    CUST5454   Outlet_C     Sushi    9/2/2023      9/4/2023
# ...         ...         ...        ...       ...         ...           ...
# 9995  ORD009996    CUST1954   Outlet_B    Burger   6/21/2023     6/22/2023
# 9996  ORD009997    CUST5428   Outlet_C     Pasta   8/28/2023     8/30/2023
# 9997  ORD009998    CUST8672   Outlet_C     Salad  11/15/2023    11/17/2023
# 9998  ORD009999    CUST3187   Outlet_D      Wrap   1/18/2023     1/20/2023
# 9999  ORD010000    CUST4321   Outlet_B     Pizza    8/2/2023      8/3/2023
#
# ...

# %%
Unit_Price_sum = df.groupby("cost_name",observed=True)["Unit_Price"].sum()

# %%
Unit_Price_sum
# Out:
# cost_name
# <10k           10.00
# 10-50k       5431.48
# 50-100k      9211.46
# 100-500k    12423.31
# 500k-1m     17121.59
# 1-5m        18325.05
# 5-10m       22284.03
# 50m         26862.15
# Name: Unit_Price, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.bar(Unit_Price_sum.index.astype(str), Unit_Price_sum.values,color="skyblue")
plt.title("Total gift shop by cost name")
plt.xlabel("Cost Name")
plt.ylabel("Total gift shop")
plt.xticks(rotation=45)
plt.grid(True, axis="y")
plt.tight_layout()
plt.show()
